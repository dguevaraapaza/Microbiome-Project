# %% [markdown]
# # **Generating Taxonomic Profile from Microbiome Data**

# %% [markdown]
# ## **1. Generating artifact**

# %%
##### FASTAQ to Artifact #####
# import the fasta files into a QIIME2 artifact
# !qiime tools import \
  --type 'SampleData[SequencesWithQuality]' \
  --input-format SingleEndFastqManifestPhred33V2 \
  --input-path manifest.tsv \
  --output-path sequences.qza
# Out:
# Imported manifest.tsv as SingleEndFastqManifestPhred33V2 to sequences.qza

# %%
##### Artifact to Visualization #####
# QIIME to visualize our sequencing data.
# !qiime demux summarize \
	--i-data sequences.qza \
	--o-visualization qualities.qzv
# Out:
# Saved Visualization to: qualities.qzv

# %%
# visualize
# !qiime tools view qualities.qzv
# Out:
# Press the 'q' key, Control-C, or Control-D to quit. This view may no longer be accessible or work correctly after quitting.Opening in existing browser session.
#
# Press the 'q' key, Control-C, or Control-D to quit. This view may no longer be accessible or work correctly after quitting.

# %% [markdown]
# ## **2. Denoise/Demultiplex data**

# %%
##### Quality Filtering: From Sequence to ASV ##### Change the trunc-len to 250
# !qiime dada2 denoise-single \
    --i-demultiplexed-seqs sequences.qza \
    --p-trunc-len 250 \
    --p-n-threads 4 \
    --output-dir dada --verbose
# Out:
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: run_dada.R --input_directory /tmp/qiime2/davo/data/356c47dc-2fe3-48f9-a044-3371720cda23/data --output_path /tmp/tmpbptgo5n3/output.tsv.biom --output_track /tmp/tmpbptgo5n3/track.tsv --filtered_directory /tmp/tmpbptgo5n3 --truncation_length 250 --trim_left 0 --max_expected_errors 2.0 --truncation_quality_score 2 --max_length Inf --pooling_method independent --chimera_method consensus --min_parental_fold 1.0 --allow_one_off False --num_threads 4 --learn_min_reads 1000000 --homopolymer_gap_penalty NULL --band_size 16
#
# R version 4.3.3 (2024-02-29)
# Loading required package: Rcpp
# DADA2: 1.30.0 / Rcpp: 1.0.13.1 / RcppParallel: 5.1.9
# 2) Filtering ..................................................................................................................................................................................
# 3) Learning Error Rates
# 259935750 total bases in 1039743 reads from 53 samples will be used for learning the error rates.
# 4) Denoise samples
# ..................................................................................................................................................................................
# 5) Remove chimeras (method = consensus)
# 6) Report read numbers through the pipeline
# 7) Write output
# Saved FeatureTable[Frequency] to: dada/table.qza
# Saved FeatureData[Sequence] to: dada/representative_sequences.qza
# Saved SampleData[DADA2Stats] to: dada/denoising_stats.qza

# %% [markdown]
# ## **3. Generating OTU**

# %%
# Denoising statistics
# !qiime metadata tabulate \
    --m-input-file dada/denoising_stats.qza \
    --o-visualization denoising-stats.qzv
# Out:
# Saved Visualization to: denoising-stats.qzv

# %%
# Feature table summary
# !qiime feature-table summarize \
  --i-table ./dada/table.qza \
  --m-sample-metadata-file ./metadata.tsv \
  --o-visualization ./dada_freqtable.qzv
# Out:
# Saved Visualization to: ./dada_freqtable.qzv

# %%
# visualize 
# !qiime tools view ./dada_freqtable.qzv
# Out:
# Press the 'q' key, Control-C, or Control-D to quit. This view may no longer be accessible or work correctly after quitting.Opening in existing browser session.
#
# Press the 'q' key, Control-C, or Control-D to quit. This view may no longer be accessible or work correctly after quitting.

# %% [markdown]
# ## **4. Taxonomic Classification (math features to labels)**

# %%
# get the classifier
# !wget -nv -O \
  "silva-138-99-nb-classifier.qza" \
  "https://data.qiime2.org/classifiers/sklearn-1.4.2/silva/silva-138-99-nb-classifier.qza"
# Out:
# 2024-12-08 05:50:58 URL:https://s3-us-west-2.amazonaws.com/qiime2-data/classifiers/sklearn-1.4.2/silva/silva-138-99-nb-classifier.qza [218245868/218245868] -> "silva-138-99-515-806-nb-classifier.qza" [1]

# %%
# expoert the table
# !qiime tools export \
  --input-path dada/table.qza \
  --output-path exported_table
# Out:
# Exported dada/table.qza as BIOMV210DirFmt to directory exported_table

# %%
# convert biom into csv
# !biom convert \
# 	-i exported_table/feature-table.biom \
# 	-o exported_table/otu_table.csv --to-tsv

## TRICKY NOT NECESSARY

# %%
# Get taxonomic OTU
# !qiime feature-classifier classify-sklearn \
  --i-classifier silva-138-99-nb-classifier.qza \
  --i-reads ./dada/representative_sequences.qza \
  --o-classification taxonomy.qza
# Out:
# Saved FeatureData[Taxonomy] to: taxonomy.qza

# %%
# convert biom into csv
# !biom convert \
	-i exported_table/feature-table.biom \
	-o exported_table/otu_table.csv --to-tsv

# %% [markdown]
# ### Extract taxonomy

# %%
# !qiime taxa collapse \
  --i-table ./dada/table.qza  \
  --i-taxonomy taxonomy.qza \
  --p-level 6 \
  --o-collapsed-table collapsed_family_table.qza
# Out:
# Saved FeatureTable[Frequency] to: collapsed_family_table.qza

# %%
# !qiime tools export \
  --input-path collapsed_family_table.qza \
  --output-path exported_family_table
# Out:
# Exported collapsed_family_table.qza as BIOMV210DirFmt to directory exported_family_table

# %%
# visualize
import biom
import pandas as pd

taxon = biom.load_table('exported_family_table/feature-table.biom')
taxon = taxon.to_dataframe()

# %%
taxon
# Out:
#                                                      206534   206536  206538  \
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  13855.0  12252.0  5345.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...    652.0    570.0   201.0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...   1713.0   1871.0  1022.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...   2149.0   1203.0  1052.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...     30.0     40.0    17.0
# ...                                                     ...      ...     ...
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...        0        0       0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...        0        0       0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...        0        0       0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...        0        0       0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Pept...        0        0       0
#
#                                                     206547  206548  206561  \
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...     4.0    27.0  3807.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...     5.0    23.0  2887.0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...  7127.0  2599.0    25.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...    43.0    19.0       0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...  1270.0   124.0       0
# ...                                                    ...     ...     ...
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...       0       0       0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...       0       0       0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...       0       0       0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...       0       0       0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Pept...       0       0       0
#
#                                                     206562  206563  206564  \
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  5954.0  5657.0  1060.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...  6126.0  7048.0  1276.0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...    43.0    22.0   139.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...    15.0       0       0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...       0       0       0
# ...                                                    ...     ...     ...
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...       0       0       0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...       0       0       0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...       0       0       0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...       0       0       0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Pept...       0       0       0
#
#                                                     206569  ...   222171  \
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  8001.0  ...  12555.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...  3372.0  ...   2197.0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...     2.0  ...     34.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...   120.0  ...     84.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...       0  ...        0
# ...                                                    ...  ...      ...
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...       0  ...        0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...       0  ...        0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...       0  ...        0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...       0  ...        0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Pept...       0  ...        0
#
#                                                      224323   224324   224325  \
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  18068.0  27582.0  16909.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...   6179.0   4676.0   5388.0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...   1926.0   2501.0   2335.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...   1881.0   1230.0    500.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...    134.0     61.0        0
# ...                                                     ...      ...      ...
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...        0        0        0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...        0        0        0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...        0        0        0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...        0      2.0        0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Pept...        0      2.0        0
#
#                                                      224326   224327   224328  \
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  14085.0  20334.0  23465.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...   6230.0   8292.0   7873.0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...   2555.0   4727.0   4011.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...    680.0   1227.0   1708.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...        0   1200.0    981.0
# ...                                                     ...      ...      ...
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...        0        0        0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...        0        0        0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...        0        0        0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...        0        0        0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Pept...        0        0        0
#
#                                                      224330  224844   224845
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...  19140.0  5663.0  11811.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...   3787.0  6680.0  14629.0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...     99.0   547.0    299.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...    182.0    86.0    142.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...    187.0       0        0
# ...                                                     ...     ...      ...
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...        0       0        0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...        0       0        0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...        0       0      2.0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Osci...        0       0        0
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Pept...        0       0        0
#
# [710 rows x 178 columns]

# %%
df_split = taxon.index.str.split(';', expand=True).to_frame().reset_index(drop=True)
df_split
# Out:
#                0                  1                       2  \
# 0    d__Bacteria    p__Bacteroidota          c__Bacteroidia
# 1    d__Bacteria      p__Firmicutes           c__Clostridia
# 2    d__Bacteria  p__Proteobacteria  c__Gammaproteobacteria
# 3    d__Bacteria      p__Firmicutes           c__Clostridia
# 4    d__Bacteria      p__Firmicutes           c__Clostridia
# ..           ...                ...                     ...
# 705  d__Bacteria  p__Proteobacteria  c__Alphaproteobacteria
# 706  d__Bacteria      p__Firmicutes           c__Clostridia
# 707  d__Bacteria  p__Proteobacteria  c__Gammaproteobacteria
# 708  d__Bacteria      p__Firmicutes           c__Clostridia
# 709  d__Bacteria      p__Firmicutes           c__Clostridia
#
#                                           3                          4  \
# 0                          o__Bacteroidales          f__Bacteroidaceae
# 1                        o__Oscillospirales         f__Ruminococcaceae
# 2                       o__Enterobacterales      f__Enterobacteriaceae
# 3                         o__Lachnospirales         f__Lachnospiraceae
# 4                         o__Lachnospirales         f__Lachnospiraceae
# ..                                      ...                        ...
# 705                          o__Rhizobiales            f__Rhizobiaceae
# 706                        o__Clostridiales        f__Caloramatoraceae
# 707                      o__Burkholderiales          f__Rhodocyclaceae
# 708                      o__Oscillospirales  f__Hungateiclostridiaceae
# 709  o__Peptostreptococcales-Tissierellales               f__Family_XI
#
#                                    5
# 0                     g__Bacteroides
# 1                g__Faecalibacterium
# 2            g__Escherichia-Shigella
# 3    g__[Ruminococcus]_torques_group
# 4     g__[Ruminococcus]_gnavus_group
# ..                               ...
# 705                  g__Ochrobactrum
# 706                               __
# 707                               __
# 708            g__Saccharofermentans
# 709                     g__Gallicola
#
# [710 rows x 6 columns]

# %% [markdown]
# ### Get table for model

# %%
### Combine OTU and Taxonomy data
import biom
import pandas as pd

# Load the OTU table
otu = biom.load_table('exported_table/feature-table.biom')
otu = otu.to_dataframe()

# Load the taxonomy table
taxonomy = pd.read_csv('exported_table/taxonomy.tsv', sep='\t', index_col=0)

# Merge the OTU table with the taxonomy table
otu_taxonomy_merged = pd.merge(otu, taxonomy, left_index=True, right_index=True)

# Save the merged table to a CSV file
otu_taxonomy_merged.to_csv('otu_with_taxonomy.csv')

# %%
print(otu_taxonomy_merged['Confidence'].describe())
# Out:
# count    5350.000000
# mean        0.948876
# std         0.079536
# min         0.315809
# 25%         0.927707
# 50%         0.992918
# 75%         0.999658
# max         1.000000
# Name: Confidence, dtype: float64

# %%
otu_taxonomy_merged
# Out:
#                                    206534   206536  206538  206547  206548  \
# 668fdb718997fc1589c7817655d4bb5f      6.0      9.0     4.0     4.0    19.0
# a3f36ef32153f2fc2aaeac2feb23777f    482.0    509.0   159.0       0       0
# 9496d87b94d90dff068f0716603930bd  11952.0  10357.0  4574.0       0       0
# 1b158b8b2922d4fcad5d9cea607cbb7d   1536.0   1648.0   805.0  7117.0  2599.0
# 23fed68c6c76ab10ba1be8a43e9176e7        0        0       0     5.0       0
# ...                                   ...      ...     ...     ...     ...
# 51946b237d59929b4f666bb5229fbacf        0        0       0       0       0
# 2707ca30f01ee8e07aa645b208068852        0        0       0       0       0
# 46b10e705d5fbdc5c8d8f3a24249591e        0        0       0       0       0
# 4c5ce916f019b3ba5d0fa994d24aee1a        0        0       0       0       0
# 530d3f556e633849ac4580c76fdda317        0        0       0       0       0
#
#                                   206561  206562  206563  206564  206569  ...  \
# 668fdb718997fc1589c7817655d4bb5f  1699.0  3325.0  3262.0   633.0  4924.0  ...
# a3f36ef32153f2fc2aaeac2feb23777f   750.0  2543.0  4525.0   767.0   742.0  ...
# 9496d87b94d90dff068f0716603930bd    35.0    91.0   455.0   102.0    37.0  ...
# 1b158b8b2922d4fcad5d9cea607cbb7d    25.0    43.0    22.0   139.0     2.0  ...
# 23fed68c6c76ab10ba1be8a43e9176e7   173.0   453.0   451.0    98.0   214.0  ...
# ...                                  ...     ...     ...     ...     ...  ...
# 51946b237d59929b4f666bb5229fbacf       0       0       0       0       0  ...
# 2707ca30f01ee8e07aa645b208068852       0       0       0       0       0  ...
# 46b10e705d5fbdc5c8d8f3a24249591e       0       0       0       0       0  ...
# 4c5ce916f019b3ba5d0fa994d24aee1a       0       0       0       0       0  ...
# 530d3f556e633849ac4580c76fdda317       0       0       0       0       0  ...
#
#                                    224324  224325  224326   224327   224328  \
# 668fdb718997fc1589c7817655d4bb5f  12783.0  6685.0  5904.0  10805.0  12100.0
# a3f36ef32153f2fc2aaeac2feb23777f   4024.0  1374.0  1739.0   6074.0   6076.0
# 9496d87b94d90dff068f0716603930bd        0       0    10.0   6495.0   8555.0
# 1b158b8b2922d4fcad5d9cea607cbb7d   2495.0  2329.0  2483.0   4712.0   4008.0
# 23fed68c6c76ab10ba1be8a43e9176e7     36.0  2154.0  2414.0    471.0    313.0
# ...                                   ...     ...     ...      ...      ...
# 51946b237d59929b4f666bb5229fbacf        0       0       0        0        0
# 2707ca30f01ee8e07aa645b208068852        0       0       0        0        0
# 46b10e705d5fbdc5c8d8f3a24249591e        0       0       0        0        0
# 4c5ce916f019b3ba5d0fa994d24aee1a        0       0       0        0        0
# 530d3f556e633849ac4580c76fdda317        0       0       0        0        0
#
#                                    224330  224844  224845  \
# 668fdb718997fc1589c7817655d4bb5f  17885.0  1708.0  6589.0
# a3f36ef32153f2fc2aaeac2feb23777f   2694.0  4684.0  9331.0
# 9496d87b94d90dff068f0716603930bd        0       0       0
# 1b158b8b2922d4fcad5d9cea607cbb7d     99.0   547.0   299.0
# 23fed68c6c76ab10ba1be8a43e9176e7     13.0   441.0  1034.0
# ...                                   ...     ...     ...
# 51946b237d59929b4f666bb5229fbacf        0       0     2.0
# 2707ca30f01ee8e07aa645b208068852        0       0     2.0
# 46b10e705d5fbdc5c8d8f3a24249591e        0       0     2.0
# 4c5ce916f019b3ba5d0fa994d24aee1a        0       0     2.0
# 530d3f556e633849ac4580c76fdda317        0       0     2.0
#
#                                                                               Taxon  \
# 668fdb718997fc1589c7817655d4bb5f  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# a3f36ef32153f2fc2aaeac2feb23777f  d__Bacteria;p__Firmicutes;c__Clostridia;o__Osc...
# 9496d87b94d90dff068f0716603930bd  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 1b158b8b2922d4fcad5d9cea607cbb7d  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...
# 23fed68c6c76ab10ba1be8a43e9176e7  d__Bacteria;p__Firmicutes;c__Clostridia;o__Osc...
# ...                                                                             ...
# 51946b237d59929b4f666bb5229fbacf  d__Bacteria;p__Firmicutes;c__Clostridia;o__Lac...
# 2707ca30f01ee8e07aa645b208068852  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...
# 46b10e705d5fbdc5c8d8f3a24249591e  d__Bacteria;p__Firmicutes;c__Clostridia;o__Chr...
# 4c5ce916f019b3ba5d0fa994d24aee1a  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...
# 530d3f556e633849ac4580c76fdda317  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
#
#                                   Confidence
# 668fdb718997fc1589c7817655d4bb5f    0.999984
# a3f36ef32153f2fc2aaeac2feb23777f    0.990108
# 9496d87b94d90dff068f0716603930bd    0.999978
# 1b158b8b2922d4fcad5d9cea607cbb7d    0.908560
# 23fed68c6c76ab10ba1be8a43e9176e7    0.996007
# ...                                      ...
# 51946b237d59929b4f666bb5229fbacf    0.765569
# 2707ca30f01ee8e07aa645b208068852    0.984180
# 46b10e705d5fbdc5c8d8f3a24249591e    0.822727
# 4c5ce916f019b3ba5d0fa994d24aee1a    0.988518
# 530d3f556e633849ac4580c76fdda317    0.999795
#
# [5350 rows x 180 columns]

# %%
df_split = otu_taxonomy_merged.Taxon.str.split(';', expand=True).reset_index(drop=True)
df_split
# Out:
#                 0                  1                       2  \
# 0     d__Bacteria    p__Bacteroidota          c__Bacteroidia
# 1     d__Bacteria      p__Firmicutes           c__Clostridia
# 2     d__Bacteria    p__Bacteroidota          c__Bacteroidia
# 3     d__Bacteria  p__Proteobacteria  c__Gammaproteobacteria
# 4     d__Bacteria      p__Firmicutes           c__Clostridia
# ...           ...                ...                     ...
# 5345  d__Bacteria      p__Firmicutes           c__Clostridia
# 5346  d__Bacteria  p__Proteobacteria  c__Gammaproteobacteria
# 5347  d__Bacteria      p__Firmicutes           c__Clostridia
# 5348  d__Bacteria  p__Proteobacteria  c__Gammaproteobacteria
# 5349  d__Bacteria    p__Bacteroidota          c__Bacteroidia
#
#                           3                       4  \
# 0          o__Bacteroidales       f__Bacteroidaceae
# 1        o__Oscillospirales      f__Ruminococcaceae
# 2          o__Bacteroidales       f__Bacteroidaceae
# 3       o__Enterobacterales   f__Enterobacteriaceae
# 4        o__Oscillospirales      f__Ruminococcaceae
# ...                     ...                     ...
# 5345      o__Lachnospirales      f__Lachnospiraceae
# 5346     o__Burkholderiales       f__Rhodocyclaceae
# 5347  o__Christensenellales  f__Christensenellaceae
# 5348     o__Burkholderiales       f__Sutterellaceae
# 5349       o__Bacteroidales        f__Rikenellaceae
#
#                                      5     6
# 0                       g__Bacteroides   s__
# 1                  g__Faecalibacterium   s__
# 2                       g__Bacteroides   s__
# 3              g__Escherichia-Shigella   s__
# 4                  g__Faecalibacterium   s__
# ...                                ...   ...
# 5345                      g__Roseburia   s__
# 5346                              None  None
# 5347  g__Christensenellaceae_R-7_group   s__
# 5348                     g__Sutterella   s__
# 5349                      g__Alistipes   s__
#
# [5350 rows x 7 columns]

# %% [markdown]
# ## **6. Alpha Rarefaction and Selecting a Rarefaction Depth**

# %%
# calculate rarefaction
# !qiime diversity alpha-rarefaction \
  --i-table ./dada/table.qza \
  --m-metadata-file metadata.tsv \
	--p-min-depth 10 \
  --p-max-depth 4900 \
  --o-visualization alpha_rarefaction_curves.qzv
# Out:
# Saved Visualization to: alpha_rarefaction_curves.qzv

# %%
# visualize empress
# !qiime tools view alpha_rarefaction_curves.qzv
# Out:
# Press the 'q' key, Control-C, or Control-D to quit. This view may no longer be accessible or work correctly after quitting.Opening in existing browser session.
#
# Press the 'q' key, Control-C, or Control-D to quit. This view may no longer be accessible or work correctly after quitting.

# %% [markdown]
# ## **3. Phylogenetics**

# %%
# Aligning sequences and constructing a phylogenetic tree with QIIME2
# !qiime phylogeny align-to-tree-mafft-fasttree \
	--i-sequences dada/representative_sequences.qza \
	--output-dir tree
# Out:
# ^C
#
# Aborted!

# %%
# Visualization for the tree using the empress QIIME 2 plugin
# !qiime empress tree-plot \
	--i-tree tree/rooted_tree.qza \
	--o-visualization tree/empress.qzv
# Out:
# Saved Visualization to: tree/empress.qzv

# %%
# expoert the table
# !qiime tools export \
  --input-path taxonomy.qza \
  --output-path exported_table
# Out:
# Exported taxonomy.qza as TSVTaxonomyDirectoryFormat to directory exported_table

# %%
# visualize empress
# !qiime tools view tree/empress.qzv
# Out:
# Press the 'q' key, Control-C, or Control-D to quit. This view may no longer be accessible or work correctly after quitting.Opening in existing browser session.
#
# Press the 'q' key, Control-C, or Control-D to quit. This view may no longer be accessible or work correctly after quitting.
