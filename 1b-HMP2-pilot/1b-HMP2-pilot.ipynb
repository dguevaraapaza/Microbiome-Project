# %%
import requests
from bs4 import BeautifulSoup
import wget
import os
import missingno as msno
import matplotlib.pyplot as plt
import pandas as pd

pd.set_option('display.max_rows', None)

# %%
##### Fetch and download amplicon data #####

# URL of the page with the .fastq.gz files
url = 'https://ibdmdb.org/downloads/html/rawfiles_HMP2_pilot.html'

# Send a GET request to fetch the page content
response = requests.get(url)
response.raise_for_status()  # Check for successful request

# Parse the HTML content
soup = BeautifulSoup(response.text, 'html.parser')

# Create a directory to save downloaded files
os.makedirs("fastq_files", exist_ok=True)

# Find all links to .fastq.gz files and download them
for link in soup.find_all('a', href=True):
    file_url = link['href']
    if file_url.endswith('.fastq.tgz'):
        # Full URL of the file
        print(f"Downloading {file_url}")
        # Download and save the file
        wget.download(file_url, out='fastq_files')

print("Download complete.")
# Out:
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD8J.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5GEZ1.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLGN.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLHA.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5ME9D.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5MEE6.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLEZ.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLGR.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD4U.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD3L.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCVZ.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD8N.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCUA.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD4W.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5ME9H.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCVF.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5GEZ6.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD5H.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCVD.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLHK.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLHI.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5MEE2.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5MEDZ.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLIK.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLFU.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM633FF.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5MEAB.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5FZBT.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLHV.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5FZBU.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLGJ.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5GEZ3.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5FZBR.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCUY.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5FZ9Q.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLD8.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCUK.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLFG.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLD6.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLE3.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD82.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCVX.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLGP.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5MEBL.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLHQ.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5GEYW.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD86.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLHG.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLHO.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD3J.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5FZBP.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5FZ9S.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5FZ42.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLHX.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLGF.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5ME9G.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCUE.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCU8.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCVB.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCUI.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5GEYY.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5GEYX.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLGD.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCV5.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5FZ9Z.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5FZ44.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD7Z.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5FZ3Z.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLI4.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLFK.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLFM.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCWI.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5YRY7.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLHZ.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCUU.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLEL.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLGT.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLFQ.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5MEET.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5FZ4G.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD8A.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5FZ3T.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5FZ4E.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD3W.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLH8.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCW8.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCU6.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD4R.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5GEZA.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLHM.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLIE.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD4B.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCTZ.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5FZ3R.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCUG.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5FZ48.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5FZ3N.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD4A.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLE9.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5FZ9X.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLFO.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5FZ4C.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5MEEB.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLIM.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD59.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5FZA2.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCWM.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5GEZ8.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5MEA7.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLEH.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLH6.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLIO.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5FZ3X.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCVV.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD47.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCVJ.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLEB.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLHE.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD5K.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLH4.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCUS.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD7W.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLIC.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCU4.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD8P.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5FZ3V.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCVH.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5MEBQ.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLIQ.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLI8.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5FZ9V.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5FZ4Q.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5FZBQ.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5MEBA.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLEN.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5ZOJY.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLGX.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLII.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5GEYU.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLE5.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLIG.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLHR.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD4C.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCUC.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5FZ8Y.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLH2.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLGH.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5FZ4K.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5FZC2.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5FZ9T.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5MEEA.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD8F.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLE7.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD51.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5FZ4A.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLIS.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD4P.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5MEA9.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCV1.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCUW.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5FZ9N.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5FZ46.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD87.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCV3.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD4S.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5FZ4I.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLEX.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5FZ4O.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLI2.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCWK.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5MEEG.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5GEZ4.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/CSM5MCUQ.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5MEBP.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLI6.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/HSM5MD57.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLFS.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5MEEJ.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/MSM5LLGV.fastq.tgz
# Downloading https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/raw/HMP2_Pilot/16S/ESM5MEEC.fastq.tgz
# Download complete.

# %%
import os
import tarfile
import gzip
from tqdm import tqdm  # For progress bar

def process_tgz_files(input_dir, output_dir):
    """
    Decompress all .tgz files in input_dir and recompress them to .gz in output_dir.

    Parameters:
        input_dir (str): Directory containing .tgz files.
        output_dir (str): Directory to save .gz files.
    """
    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # List all .tgz files in the input directory
    tgz_files = [f for f in os.listdir(input_dir) if f.endswith('.tgz')]

    if not tgz_files:
        print(f"No .tgz files found in {input_dir}")
        return

    print(f"Found {len(tgz_files)} .tgz files to process.")

    # Loop through each .tgz file
    for tgz_file in tqdm(tgz_files, desc="Processing files"):
        input_path = os.path.join(input_dir, tgz_file)
        output_file = tgz_file.replace('.tgz', '.gz')
        output_path = os.path.join(output_dir, output_file)

        # Temporary directory to hold extracted contents
        temp_dir = os.path.join(input_dir, "temp_extracted")
        os.makedirs(temp_dir, exist_ok=True)

        try:
            # Step 1: Decompress .tgz (tar.gz)
            with tarfile.open(input_path, mode='r:gz') as tar:
                tar.extractall(path=temp_dir)

            # Step 2: Find the extracted file(s)
            extracted_files = [os.path.join(temp_dir, f) for f in os.listdir(temp_dir)]
            if len(extracted_files) != 1:
                raise ValueError(f"Expected one file in the archive, found {len(extracted_files)} in {tgz_file}.")

            extracted_file = extracted_files[0]

            # Step 3: Compress the extracted file into .gz (gzip)
            with open(extracted_file, 'rb') as f_in, gzip.open(output_path, 'wb') as f_out:
                f_out.writelines(f_in)

        except Exception as e:
            print(f"Error processing {tgz_file}: {e}")

        finally:
            # Cleanup: Remove temporary files
            for file in extracted_files:
                os.remove(file)
            os.rmdir(temp_dir)

    print(f"All files processed. Converted .tgz files are saved in {output_dir}.")

# Define input and output directories
input_directory = "./fastq_files"
output_directory = "./fastq_files_converted"

# Process the files
process_tgz_files(input_directory, output_directory)
# Out:
# Found 180 .tgz files to process.
# Processing files:   0%|          | 0/180 [00:00<?, ?it/s]
# Processing files: 100%|██████████| 180/180 [48:16<00:00, 16.09s/it]
# All files processed. Converted .tgz files are saved in ./fastq_files_converted.

# %%
###### Create manifest ######

# Directory containing the downloaded fastq files
directory = './fastq_files_converted'

# Prepare data for the manifest
data = []
for filename in os.listdir(directory):
    if filename.endswith('.fastq.gz'):
        sample_id = filename.split('.')[0]  # Extract sample ID from filename
        absolute_path = os.path.join('$PWD', directory, filename)  # Create absolute path with $PWD
        data.append({'sample-id': sample_id, 'absolute-filepath': absolute_path}) # for colab
        # data.append({'sample-id': sample_id, 'forward-absolute-filepath': absolute_path}) # debug

# Create a DataFrame
manifest_df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
manifest_df.to_csv('manifest.tsv',sep='\t', index=None)

# Show the manifest DataFrame
manifest_df.head()
# Out:
#   sample-id                               absolute-filepath
# 0  CSM5MCVX  $PWD/./fastq_files_converted/CSM5MCVX.fastq.gz
# 1  CSM5MCUS  $PWD/./fastq_files_converted/CSM5MCUS.fastq.gz
# 2  ESM5ME9H  $PWD/./fastq_files_converted/ESM5ME9H.fastq.gz
# 3  HSM5MD8P  $PWD/./fastq_files_converted/HSM5MD8P.fastq.gz
# 4  MSM5LLGR  $PWD/./fastq_files_converted/MSM5LLGR.fastq.gz
